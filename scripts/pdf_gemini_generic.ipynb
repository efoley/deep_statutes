# %%
import os
from enum import auto, Enum, StrEnum

from google import genai
from google.genai import types
from pydantic import BaseModel

from deep_statutes.config import STATUTES_DATA_DIR
from deep_statutes.states import ABBREV_TO_US_STATE

# %%
state = 'WY'

pdf_path = STATUTES_DATA_DIR / state.lower() / "pdf" / "title21.pdf"
api_key = os.getenv("GEMINI_API_KEY")

# %%
model_flash = "gemini-2.5-flash-preview-04-17"
model_pro = "gemini-2.5-pro-exp-03-25"

no_thinking = thinking_config=types.ThinkingConfig(thinking_budget=0)

# %%
client = genai.Client(api_key=api_key)

gem_doc = client.files.upload(file=pdf_path, display_name=pdf_path.name)

system_instruction = """
You are a legal assistant. You will be provided with a legal document.

You will be asked questions about the structure of the document.
How is the document structured hierarchically? Example header names for levels in this hierarchy are: "Title", "Chapter", "Section", "Article".
What are header names within the document?

Note that often sections are not labeled with the word "Section" but can be identified by their numbering, e.g. "21-1-102."
"""

cache = client.caches.create(
    model=model_flash,
    config=types.CreateCachedContentConfig(
        system_instruction=system_instruction,
        contents=[gem_doc],
    ),
)

# %%
cache
# Out:
# CachedContent(name='cachedContents/av3jvs7ze9re', display_name='', model='models/gemini-2.5-flash-preview-04-17', create_time=datetime.datetime(2025, 4, 25, 15, 33, 4, 51801, tzinfo=TzInfo(UTC)), update_time=datetime.datetime(2025, 4, 25, 15, 33, 4, 51801, tzinfo=TzInfo(UTC)), expire_time=datetime.datetime(2025, 4, 25, 16, 31, 56, 22155, tzinfo=TzInfo(UTC)), usage_metadata=CachedContentUsageMetadata(audio_duration_seconds=None, image_count=None, text_count=None, total_token_count=146358, video_duration_seconds=None))

# %%
prompt = """
Please provide a list of the header types in the document.

This list should be like:
['Title', 'Chapter', 'Article']
or
['Title', 'Article', 'Part']
where the first element is the highest level of the hierarchy and the last element is the lowest level.

Use this schema for the response:
Return: list[str]
"""

config = types.GenerateContentConfig(
    cached_content=cache.name,
    temperature=0.2,
    response_mime_type='application/json',
    response_schema=list[str],
)
response = client.models.generate_content(
    model=model_flash,
    config=config,
    contents=prompt,
)

print(response.text)
# Out:
# [
#   "Title",
#   "Chapter",
#   "Article",
#   "Section"
# ]

# %%
header_types = response.parsed
header_types = [header_type.capitalize() for header_type in header_types]

header_types
# Out:
# ['Title', 'Chapter', 'Article', 'Section']

# %%
HeaderType = StrEnum("HeaderType", header_types[:-1])

class Header(BaseModel):
    type: HeaderType
    text: str
    sub_text: str 
    page: int

# %%
state_name = ABBREV_TO_US_STATE[state]

prompt = f"""
This document is a legal document containing a portion of laws of {state_name}.

It is structured hierarchically with header types: {header_types}.

Please make a table of contents for the document including every header and its page number.
"""

prompt += """The output should be a JSON array of objects with schema like:
[
    {
        "type": "title",
        "text": "TITLE 1",
        "sub_text": "GENERAL PROVISIONS",
        "page": 1
    },
    {
        "type": "article",
        "text": "ARTICLE 1",
        "sub_text": "Application of procedures act",
        "page": 2
    },
    {
        "type": "part",
        "text": "PART 1",
        "sub_text": "",
        "page": 3
    }
]
"""

config = types.GenerateContentConfig(
    cached_content=cache.name,
    temperature=0.2,
    response_mime_type='application/json',
    response_schema=list[Header],
)
response = client.models.generate_content(
    model=model_flash,
    config=config,
    contents=prompt,
)

print(response.text)
# Out:
# [
#   {
#     "type": "title",
#     "text": "TITLE 21",
#     "sub_text": "EDUCATION",
#     "page": 1
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 1",
#     "sub_text": "GENERAL PROVISIONS AND DEFINITIONS",
#     "page": 1
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 1",
#     "sub_text": "GENERAL PROVISIONS",
#     "page": 1
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 2",
#     "sub_text": "THE ADMINISTRATION OF THE STATE SYSTEM OF EDUCATION AT THE STATE LEVEL",
#     "page": 1
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 1",
#     "sub_text": "GENERAL PROVISIONS",
#     "page": 1
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 2",
#     "sub_text": "SUPERINTENDENT OF PUBLIC INSTRUCTION AND DEPARTMENT OF EDUCATION",
#     "page": 2
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 3",
#     "sub_text": "STATE BOARD OF EDUCATION",
#     "page": 28
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 4",
#     "sub_text": "PRIVATE SCHOOL LICENSING",
#     "page": 37
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 5",
#     "sub_text": "EDUCATION OF CHILDREN WITH DISABILITIES",
#     "page": 44
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 6",
#     "sub_text": "FEDERAL AID",
#     "page": 44
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 7",
#     "sub_text": "SERVICES TO PRESCHOOL CHILDREN WITH DISABILITIES",
#     "page": 45
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 8",
#     "sub_text": "WYOMING PROFESSIONAL TEACHING STANDARDS BOARD",
#     "page": 50
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 9",
#     "sub_text": "WYOMING EDUCATION SAVINGS ACCOUNTS",
#     "page": 54
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 3",
#     "sub_text": "SCHOOL DISTRICTS IN GENERAL",
#     "page": 65
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 1",
#     "sub_text": "IN GENERAL",
#     "page": 65
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 2",
#     "sub_text": "CHARTER SCHOOLS",
#     "page": 97
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 3",
#     "sub_text": "CHARTER SCHOOLS",
#     "page": 97
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 4",
#     "sub_text": "READING ASSESSMENT AND INTERVENTION",
#     "page": 120
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 5",
#     "sub_text": "DRIVER'S EDUCATION PROGRAMS",
#     "page": 123
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 4",
#     "sub_text": "PUPILS",
#     "page": 125
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 1",
#     "sub_text": "COMPULSORY ATTENDANCE",
#     "page": 125
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 2",
#     "sub_text": "ENUMERATION",
#     "page": 129
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 3",
#     "sub_text": "RIGHT TO ATTEND SCHOOL",
#     "page": 129
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 4",
#     "sub_text": "ISOLATION",
#     "page": 145
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 5",
#     "sub_text": "TUITION",
#     "page": 147
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 6",
#     "sub_text": "AMERICAN INDIAN EDUCATION PROGRAMS",
#     "page": 152
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 5",
#     "sub_text": "SCHOOL DISTRICT ORGANIZATION",
#     "page": 154
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 1",
#     "sub_text": "IN GENERAL",
#     "page": 154
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 6",
#     "sub_text": "SCHOOL DISTRICT ORGANIZATION",
#     "page": 155
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 1",
#     "sub_text": "IN GENERAL",
#     "page": 155
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 2",
#     "sub_text": "DISTRICT BOUNDARY BOARD",
#     "page": 156
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 7",
#     "sub_text": "TEACHERS AND EMPLOYEES",
#     "page": 168
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 1",
#     "sub_text": "TEACHER CONTRACTS",
#     "page": 168
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 2",
#     "sub_text": "TEACHER SCHOLARSHIPS",
#     "page": 174
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 3",
#     "sub_text": "TEACHERS IN GENERAL",
#     "page": 174
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 4",
#     "sub_text": "EMPLOYEE SECURITY REQUIREMENTS",
#     "page": 177
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 5",
#     "sub_text": "NATIONAL CERTIFICATION",
#     "page": 177
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 6",
#     "sub_text": "WYOMING TEACHER SHORTAGE LOAN REPAYMENT PROGRAM",
#     "page": 179
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 7",
#     "sub_text": "WYOMING ADJUNCT PROFESSOR LOAN REPAYMENT PROGRAM",
#     "page": 182
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 8",
#     "sub_text": "COUNTY SUPERINTENDENT OF SCHOOLS",
#     "page": 185
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 9",
#     "sub_text": "COURSES OF STUDY, TEXTBOOKS, SUPPLIES",
#     "page": 185
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 1",
#     "sub_text": "COURSES OF STUDY",
#     "page": 185
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 2",
#     "sub_text": "FREE TEXTBOOKS AND SUPPLIES",
#     "page": 189
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 10",
#     "sub_text": "SCHOOL LUNCH PROGRAM",
#     "page": 190
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 11",
#     "sub_text": "PRIVATE SCHOOL LICENSING",
#     "page": 191
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 12",
#     "sub_text": "CAREER AND TECHNICAL EDUCATION",
#     "page": 192
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 13",
#     "sub_text": "SCHOOL FINANCE",
#     "page": 195
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 1",
#     "sub_text": "LOCAL FINANCIAL SUPPORT",
#     "page": 195
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 2",
#     "sub_text": "COUNTY FINANCIAL SUPPORT",
#     "page": 201
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 3",
#     "sub_text": "STATE FINANCIAL SUPPORT",
#     "page": 202
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 4",
#     "sub_text": "FEDERAL AID",
#     "page": 244
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 5",
#     "sub_text": "BUILDING FUND AND RESERVE FUND",
#     "page": 245
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 6",
#     "sub_text": "FUNDS FOR EMERGENCY SCHOOL CONSTRUCTION",
#     "page": 247
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 7",
#     "sub_text": "BOND ISSUES",
#     "page": 247
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 8",
#     "sub_text": "WYOMING SCHOOL BOND RESERVE ACT",
#     "page": 255
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 14",
#     "sub_text": "PROGRAM FOR HANDICAPPED CHILDREN",
#     "page": 255
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 15",
#     "sub_text": "CAPITAL CONSTRUCTION PROJECTS",
#     "page": 255
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 16",
#     "sub_text": "HIGHER EDUCATION GENERALLY",
#     "page": 288
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 1",
#     "sub_text": "WYOMING HIGHER EDUCATION LOAN PLAN",
#     "page": 288
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 2",
#     "sub_text": "WESTERN REGIONAL HIGHER EDUCATION COMPACT",
#     "page": 288
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 3",
#     "sub_text": "INTERSTATE COMPACT FOR EDUCATION",
#     "page": 296
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 4",
#     "sub_text": "HIGHER EDUCATION COUNCIL",
#     "page": 304
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 5",
#     "sub_text": "ADVANCE PAYMENT OF HIGHER EDUCATION COSTS",
#     "page": 304
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 6",
#     "sub_text": "WYOMING EDUCATION PLANNING AND COORDINATION COUNCIL",
#     "page": 304
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 7",
#     "sub_text": "WYOMING HIGHER EDUCATION ASSISTANCE AUTHORITY",
#     "page": 304
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 8",
#     "sub_text": "FAMILY COLLEGE SAVINGS PROGRAM",
#     "page": 318
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 9",
#     "sub_text": "UNIVERSITY OF WYOMING ENDOWMENT FUND",
#     "page": 319
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 10",
#     "sub_text": "UNIVERSITY OF WYOMING ATHLETICS CHALLENGE FUND",
#     "page": 323
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 11",
#     "sub_text": "WYOMING COMMUNITY COLLEGE ENDOWMENT CHALLENGE PROGRAM",
#     "page": 326
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 12",
#     "sub_text": "HIGHER EDUCATION ENDOWMENT ACCOUNTS",
#     "page": 330
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 13",
#     "sub_text": "HATHAWAY SCHOLARSHIP PROGRAM",
#     "page": 334
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 14",
#     "sub_text": "UNIVERSITY OF WYOMING ACADEMIC FACILITIES CHALLENGE FUND",
#     "page": 370
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 15",
#     "sub_text": "TUITION AND FEES FOR SURVIVORS OR DEPENDENTS OF EMERGENCY RESPONDERS",
#     "page": 372
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 16",
#     "sub_text": "UNIVERSITY OF WYOMING RECLAMATION AND RESTORATION CENTER CHALLENGE ACCOUNT",
#     "page": 376
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 17",
#     "sub_text": "COLLEGE CREDIT RETENTION",
#     "page": 378
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 18",
#     "sub_text": "HIGHER EDUCATION EXPENDITURES ON ABORTIONS",
#     "page": 378
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 19",
#     "sub_text": "WYOMING'S TOMORROW SCHOLARSHIP PROGRAM",
#     "page": 378
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 17",
#     "sub_text": "UNIVERSITY OF WYOMING",
#     "page": 386
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 1",
#     "sub_text": "IN GENERAL",
#     "page": 386
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 2",
#     "sub_text": "BOARD OF TRUSTEES",
#     "page": 410
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 3",
#     "sub_text": "AGRICULTURE AND EXTENSION WORK",
#     "page": 413
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 4",
#     "sub_text": "CAPITAL CONSTRUCTION PROJECTS",
#     "page": 420
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 18",
#     "sub_text": "COMMUNITY COLLEGES",
#     "page": 453
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 1",
#     "sub_text": "GENERALLY",
#     "page": 453
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 2",
#     "sub_text": "COMMUNITY COLLEGE COMMISSION",
#     "page": 457
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 3",
#     "sub_text": "COMMUNITY COLLEGE DISTRICTS",
#     "page": 479
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 4",
#     "sub_text": "WYOMING WORKS PROGRAM",
#     "page": 509
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 19",
#     "sub_text": "HIGHER EDUCATION RETIREMENT",
#     "page": 517
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 20",
#     "sub_text": "COOPERATIVE EDUCATIONAL SERVICES",
#     "page": 519
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 1",
#     "sub_text": "IN GENERAL",
#     "page": 520
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 2",
#     "sub_text": "WYOMING POSTSECONDARY EDUCATION OPTIONS PROGRAM",
#     "page": 528
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 21",
#     "sub_text": "COOPERATIVE TEACHER EDUCATION",
#     "page": 530
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 22",
#     "sub_text": "WYOMING EDUCATION TRUST FUND",
#     "page": 531
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 23",
#     "sub_text": "WYOMING PUBLIC TELEVISION",
#     "page": 534
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 2",
#     "sub_text": "WYOMING PUBLIC TELEVISION ENDOWMENT ACCOUNT",
#     "page": 534
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 24",
#     "sub_text": "MILITARY STUDENTS AND STUDENTS OF MILITARY FAMILIES",
#     "page": 536
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 1",
#     "sub_text": "INTERSTATE COMPACT ON STUDENTS OF MILITARY FAMILIES",
#     "page": 536
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 2",
#     "sub_text": "ADMISSION REQUIREMENTS AND PREFERENCES",
#     "page": 558
#   },
#   {
#     "type": "chapter",
#     "text": "CHAPTER 25",
#     "sub_text": "STUDENT ELIGIBILITY IN INTERSCHOLASTIC ACTIVITIES",
#     "page": 558
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 1",
#     "sub_text": "PARTICIPATION IN FEMALE SPORTS",
#     "page": 559
#   },
#   {
#     "type": "article",
#     "text": "ARTICLE 2",
#     "sub_text": "STUDENT ELIGIBILITY",
#     "page": 560
#   }
# ]
